# %%
import pandas as pd


df = pd.read_csv('coa2pc.csv', sep=';'  )

# %%
df['transf_capita'] = df['transf'] / df['popul']

# %%
df['inv_capita'] = df['inv'] / df['popul']

# %%
df.dtypes.tail()
# Out:
# transf           float64
# transf_post1     float64
# transf_post2       int64
# transf_capita    float64
# inv_capita       float64
# dtype: object

# %%
df['dif_sh']= df['sh_prez']-df['sh_gob']
df['dif_sh']
# Out:
# 0      -0.12
# 1      -0.20
# 2      -0.05
# 3      -0.07
# 4      -0.11
#         ...
# 2550     NaN
# 2551     NaN
# 2552    0.01
# 2553    0.02
# 2554   -0.13
# Name: dif_sh, Length: 2555, dtype: float64

# %%
import statsmodels.api as sm
model = sm.OLS(df['sh_prez'], sm.add_constant(df[['sh_gob'],['transf']]))
result = model.fit()
print(result.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['sh_gob'], ['transf'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import statsmodels.api as sm
# ----> 2 model = sm.OLS(df['sh_prez'], sm.add_constant(df[['sh_gob'],['transf']]))
#       3 result = model.fit()
#       4 print(result.summary())
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (['sh_gob'], ['transf'])

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf + inv", data=df).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     17.68
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           2.65e-11
# Time:                        10:11:05   Log-Likelihood:                 371.34
# No. Observations:                1719   AIC:                            -734.7
# Df Residuals:                    1715   BIC:                            -712.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3757      0.020     19.085      0.000       0.337       0.414
# sh_gob         0.2173      0.034      6.418      0.000       0.151       0.284
# transf     -2.188e-11   9.04e-12     -2.420      0.016   -3.96e-11   -4.14e-12
# inv         1.312e-11   2.31e-11      0.568      0.570   -3.22e-11    5.84e-11
# ==============================================================================
# Omnibus:                       16.010   Durbin-Watson:                   0.334
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.838
# Skew:                          -0.214   Prob(JB):                     0.000364
# Kurtosis:                       2.805   Cond. No.                     6.84e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.84e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob*core + transf", data=df).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     308.5
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):          5.38e-200
# Time:                        10:30:22   Log-Likelihood:                 811.24
# No. Observations:                1719   AIC:                            -1612.
# Df Residuals:                    1714   BIC:                            -1585.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.6650      0.023     28.329      0.000       0.619       0.711
# sh_gob         -0.5843      0.044    -13.333      0.000      -0.670      -0.498
# core           -0.3939      0.030    -13.350      0.000      -0.452      -0.336
# sh_gob:core     1.1762      0.054     21.638      0.000       1.070       1.283
# transf      -5.969e-11   6.47e-12     -9.226      0.000   -7.24e-11    -4.7e-11
# ==============================================================================
# Omnibus:                       93.178   Durbin-Watson:                   0.477
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              218.592
# Skew:                           0.318   Prob(JB):                     3.41e-48
# Kurtosis:                       4.627   Cond. No.                     1.63e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob*core + inv", data=df).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     297.3
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):          2.60e-194
# Time:                        10:30:27   Log-Likelihood:                 798.09
# No. Observations:                1719   AIC:                            -1586.
# Df Residuals:                    1714   BIC:                            -1559.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.6718      0.024     28.318      0.000       0.625       0.718
# sh_gob         -0.5958      0.044    -13.492      0.000      -0.682      -0.509
# core           -0.3929      0.030    -13.067      0.000      -0.452      -0.334
# sh_gob:core     1.1731      0.055     21.321      0.000       1.065       1.281
# inv         -1.299e-10   1.71e-11     -7.603      0.000   -1.63e-10   -9.64e-11
# ==============================================================================
# Omnibus:                       91.854   Durbin-Watson:                   0.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              228.959
# Skew:                           0.291   Prob(JB):                     1.92e-50
# Kurtosis:                       4.691   Cond. No.                     6.96e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.96e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_nn = df.dropna(subset= ["sh_gob", "transf", "sh_prez", "inv"])
df_nn
# Out:
#       year  idprov         provincia  indra         departamento  preselec  \
# 511   2007       2      Buenos Aires   2001        Adolfo Alsina         1
# 512   2007       2      Buenos Aires   2002              Alberti         1
# 513   2007       2      Buenos Aires   2003      Almirante Brown         1
# 514   2007       2      Buenos Aires   2004           Avellaneda         1
# 515   2007       2      Buenos Aires   2005             Ayacucho         1
# ...    ...     ...               ...    ...                  ...       ...
# 2506  2019      21          Santa Fe  21021           San Martin         1
# 2507  2019      21          Santa Fe  21022                 Vera         1
# 2552  2019      24  Tierra del Fuego  24001              Ushuaia         1
# 2553  2019      24  Tierra del Fuego  24002           Rio Grande         1
# 2554  2019      24  Tierra del Fuego  24003  Antartida Argentina         1
#
#      regime party_gob        elect_gob  reelec_gobp  ...    inv_post1  \
# 511     FPV       FPV    Daniel Scioli            1  ...  446540884.0
# 512     FPV       FPV    Daniel Scioli            1  ...  446540884.0
# 513     FPV       FPV    Daniel Scioli            1  ...  446540884.0
# 514     FPV       FPV    Daniel Scioli            1  ...  446540884.0
# 515     FPV       FPV    Daniel Scioli            1  ...  446540884.0
# ...     ...       ...              ...          ...  ...          ...
# 2506    FDT       FDT     Omar Perotti            0  ...  114677904.0
# 2507    FDT       FDT     Omar Perotti            0  ...  114677904.0
# 2552    FDT       FPV  Gustavo Melella            1  ...   11307649.0
# 2553    FDT       FPV  Gustavo Melella            1  ...   11307649.0
# 2554    FDT       FPV  Gustavo Melella            1  ...   11307649.0
#
#       inv_post2   transf_pre2   transf_pre1        transf  transf_post1  \
# 511   520231981  1.447641e+09  1.340762e+09  1.019932e+09   961284933.0
# 512   520231981  1.447641e+09  1.340762e+09  1.019932e+09   961284933.0
# 513   520231981  1.447641e+09  1.340762e+09  1.019932e+09   961284933.0
# 514   520231981  1.447641e+09  1.340762e+09  1.019932e+09   961284933.0
# 515   520231981  1.447641e+09  1.340762e+09  1.019932e+09   961284933.0
# ...         ...           ...           ...           ...           ...
# 2506  151937930  2.618140e+08  9.207710e+07  3.380490e+07    44085968.0
# 2507  151937930  2.618140e+08  9.207710e+07  3.380490e+07    44085968.0
# 2552   10721992  6.708399e+07  3.921140e+07  9.580784e+06    23036536.0
# 2553   10721992  6.708399e+07  3.921140e+07  9.580784e+06    23036536.0
# 2554   10721992  6.708399e+07  3.921140e+07  9.580784e+06    23036536.0
#
#       transf_post2  transf_capita  inv_capita dif_sh
# 511     1855105431      68.369468   33.788958  -0.07
# 512     1855105431      68.369468   33.788958   0.00
# 513     1855105431      68.369468   33.788958   0.06
# 514     1855105431      68.369468   33.788958   0.02
# 515     1855105431      68.369468   33.788958  -0.03
# ...            ...            ...         ...    ...
# 2506     137825887       9.633459   64.003798  -0.05
# 2507     137825887       9.633459   64.003798   0.05
# 2552      27490655      56.629709  141.038059   0.01
# 2553      27490655      56.629709  141.038059   0.02
# 2554      27490655      56.629709  141.038059  -0.13
#
# [1719 rows x 66 columns]

# %%
df_07 = df_nn[(df_nn['year'] == 2007)]

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf*core", data=df_07).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     47.97
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           1.42e-33
# Time:                        10:30:44   Log-Likelihood:                 202.97
# No. Observations:                 453   AIC:                            -395.9
# Df Residuals:                     448   BIC:                            -375.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.1158      0.049      2.366      0.018       0.020       0.212
# sh_gob          0.3179      0.050      6.308      0.000       0.219       0.417
# transf       2.281e-09   3.73e-10      6.119      0.000    1.55e-09    3.01e-09
# core            0.3650      0.041      8.880      0.000       0.284       0.446
# transf:core -2.453e-09   3.73e-10     -6.583      0.000   -3.19e-09   -1.72e-09
# ==============================================================================
# Omnibus:                        0.471   Durbin-Watson:                   0.549
# Prob(Omnibus):                  0.790   Jarque-Bera (JB):                0.510
# Skew:                          -0.077   Prob(JB):                        0.775
# Kurtosis:                       2.944   Cond. No.                     7.43e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.43e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf", data=df_07).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     45.86
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           7.49e-19
# Time:                        10:30:47   Log-Likelihood:                 164.24
# No. Observations:                 453   AIC:                            -322.5
# Df Residuals:                     450   BIC:                            -310.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4415      0.030     14.771      0.000       0.383       0.500
# sh_gob         0.3134      0.054      5.842      0.000       0.208       0.419
# transf      -1.25e-10   1.98e-11     -6.330      0.000   -1.64e-10   -8.62e-11
# ==============================================================================
# Omnibus:                       23.573   Durbin-Watson:                   0.524
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.622
# Skew:                          -0.439   Prob(JB):                     1.36e-07
# Kurtosis:                       3.952   Cond. No.                     4.37e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.37e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_11 = df_nn[(df_nn['year'] == 2011)]

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf", data=df_11).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.170
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     46.71
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           3.51e-19
# Time:                        10:30:52   Log-Likelihood:                 146.12
# No. Observations:                 459   AIC:                            -286.2
# Df Residuals:                     456   BIC:                            -273.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3941      0.030     13.331      0.000       0.336       0.452
# sh_gob         0.4305      0.051      8.376      0.000       0.330       0.532
# transf     -4.669e-11   1.06e-11     -4.403      0.000   -6.75e-11   -2.59e-11
# ==============================================================================
# Omnibus:                      144.229   Durbin-Watson:                   0.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              391.029
# Skew:                          -1.531   Prob(JB):                     1.23e-85
# Kurtosis:                       6.326   Cond. No.                     7.58e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.58e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf*core", data=df_11).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.602
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     171.4
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           2.51e-89
# Time:                        18:55:18   Log-Likelihood:                 314.58
# No. Observations:                 459   AIC:                            -619.2
# Df Residuals:                     454   BIC:                            -598.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.6586      0.028     23.585      0.000       0.604       0.714
# sh_gob          0.2570      0.039      6.626      0.000       0.181       0.333
# transf        -1.7e-09      1e-10    -16.939      0.000    -1.9e-09    -1.5e-09
# core           -0.0955      0.027     -3.581      0.000      -0.148      -0.043
# transf:core  1.616e-09   1.01e-10     16.030      0.000    1.42e-09    1.81e-09
# ==============================================================================
# Omnibus:                       22.801   Durbin-Watson:                   0.703
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.763
# Skew:                          -0.269   Prob(JB):                     7.01e-11
# Kurtosis:                       4.468   Cond. No.                     1.12e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.12e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_15 = df_nn[(df_nn['year'] == 2015)]

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf", data=df_15).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.231
# Method:                 Least Squares   F-statistic:                     73.56
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           1.34e-28
# Time:                        10:30:57   Log-Likelihood:                 394.45
# No. Observations:                 484   AIC:                            -782.9
# Df Residuals:                     481   BIC:                            -770.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3892      0.023     16.918      0.000       0.344       0.434
# sh_gob        -0.2478      0.039     -6.312      0.000      -0.325      -0.171
# transf      6.269e-11   7.94e-12      7.893      0.000    4.71e-11    7.83e-11
# ==============================================================================
# Omnibus:                        2.724   Durbin-Watson:                   0.997
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.802
# Skew:                           0.174   Prob(JB):                        0.246
# Kurtosis:                       2.869   Cond. No.                     8.35e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.35e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf + transf_post1 + transf_post2", data=df_07).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     62.63
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):           5.02e-42
# Time:                        19:13:27   Log-Likelihood:                 222.83
# No. Observations:                 453   AIC:                            -435.7
# Df Residuals:                     448   BIC:                            -415.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.4301      0.026     16.288      0.000       0.378       0.482
# sh_gob           0.3724      0.048      7.835      0.000       0.279       0.466
# transf        2.994e-10   1.14e-10      2.631      0.009    7.57e-11    5.23e-10
# transf_post1 -5.946e-11   5.45e-12    -10.903      0.000   -7.02e-11   -4.87e-11
# transf_post2 -2.159e-10   6.21e-11     -3.476      0.001   -3.38e-10   -9.38e-11
# ==============================================================================
# Omnibus:                        0.722   Durbin-Watson:                   0.586
# Prob(Omnibus):                  0.697   Jarque-Bera (JB):                0.539
# Skew:                           0.061   Prob(JB):                        0.764
# Kurtosis:                       3.117   Cond. No.                     1.20e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.2e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + transf_post1*core ", data=df_11).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     113.2
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           7.41e-67
# Time:                        10:30:59   Log-Likelihood:                 262.09
# No. Observations:                 459   AIC:                            -514.2
# Df Residuals:                     454   BIC:                            -493.5
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             0.6796      0.037     18.227      0.000       0.606       0.753
# sh_gob                0.2401      0.043      5.554      0.000       0.155       0.325
# transf_post1       -2.18e-09   1.84e-10    -11.823      0.000   -2.54e-09   -1.82e-09
# core                 -0.1023      0.036     -2.847      0.005      -0.173      -0.032
# transf_post1:core  2.065e-09   1.85e-10     11.167      0.000     1.7e-09    2.43e-09
# ==============================================================================
# Omnibus:                       12.597   Durbin-Watson:                   0.576
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               24.641
# Skew:                          -0.043   Prob(JB):                     4.46e-06
# Kurtosis:                       4.132   Cond. No.                     8.85e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.85e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="sh_prez ~ sh_gob + inv_post2 + inv_post1 + inv ", data=df_11).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sh_prez   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.212
# Method:                 Least Squares   F-statistic:                     31.71
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           2.59e-23
# Time:                        10:31:36   Log-Likelihood:                 159.90
# No. Observations:                 459   AIC:                            -309.8
# Df Residuals:                     454   BIC:                            -289.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3863      0.034     11.337      0.000       0.319       0.453
# sh_gob         0.4430      0.055      8.033      0.000       0.335       0.551
# inv_post2  -5.889e-10   6.01e-10     -0.980      0.328   -1.77e-09    5.92e-10
# inv_post1  -1.122e-09   8.09e-10     -1.387      0.166   -2.71e-09    4.68e-10
# inv         1.516e-09   4.46e-10      3.402      0.001     6.4e-10    2.39e-09
# ==============================================================================
# Omnibus:                      104.929   Durbin-Watson:                   0.382
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              231.002
# Skew:                          -1.190   Prob(JB):                     6.89e-51
# Kurtosis:                       5.532   Cond. No.                     3.88e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.88e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import statsmodels
import statsmodels.formula.api as smf
res = smf.ols(formula="dif_sh ~ pubemp + inv_capita*core ", data=df).fit()
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 dif_sh   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     31.35
# Date:                Wed, 02 Nov 2022   Prob (F-statistic):           2.27e-24
# Time:                        10:31:06   Log-Likelihood:                 250.79
# No. Observations:                 850   AIC:                            -491.6
# Df Residuals:                     845   BIC:                            -467.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -0.1930      0.029     -6.636      0.000      -0.250      -0.136
# pubemp              0.0026      0.000      6.826      0.000       0.002       0.003
# inv_capita          0.0010      0.000      4.302      0.000       0.001       0.002
# core                0.1242      0.027      4.659      0.000       0.072       0.177
# inv_capita:core    -0.0009      0.000     -3.903      0.000      -0.001      -0.000
# ==============================================================================
# Omnibus:                       82.714   Durbin-Watson:                   0.657
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              242.160
# Skew:                           0.479   Prob(JB):                     2.60e-53
# Kurtosis:                       5.433   Cond. No.                     1.20e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
